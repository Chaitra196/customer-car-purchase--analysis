# %% [markdown]
# ![cars..png](data:image/png;base64,...)

# %% [markdown]
# # **AUSTO_AUTOMOBILES CASE STUDY**

# %% [markdown]
# # **Austo_AutoMobiles**
#
# # **Context**
#
# Analysts are required to explore data and reflect on the insights. Clear writing skill is an integral part of a good report. Note that the explanations must be such that readers with minimum knowledge of analytics is able to grasp the insight.
#
# Austo Motor Company is a leading car manufacturer specializing in SUV, Sedan, and Hatchback models. In its recent board meeting, concerns were raised by the members on the efficiency of the marketing campaign currently being used. The board decides to rope in an analytics professional to improve the existing campaign.
#
#
#
# # **Objective**
#
# They want to analyze the data to get a fair idea about the demand of customers which will help them in enhancing their customer experience. Suppose you are a Data Scientist at the company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
#
#
# # **Data Description**
#
# Age: The age of the individual in years.
#
# Gender: The gender of the individual, categorized as male or female.
#
# Profession: The occupation or profession of the individual.
#
# Marital_status: The marital status of the individual, such as married &, single.
#
# Education: The educational qualification of the individual Graduate and Post Graduate.
#
# No_of_Dependents: The number of dependents (e.g., children, elderly parents) that the individual supports financially.
#
# Personal_loan: A binary variable indicating whether the individual has taken a personal loan "Yes" or "No".
#
# House_loan: A binary variable indicating whether the individual has taken a housing loan "Yes" or "No".
#
# Partner_working: A binary variable indicating whether the individual's partner is employed "Yes" or "No".
#
# Salary: The individual's salary or income.
#
# Partner_salary: The salary or income of the individual's partner, if applicable.
#
# Total_salary: The total combined salary of the individual and their partner (if applicable).
#
# Price: The price of a product or service.
#
# Make: The type of automobile

# %% [markdown]
# **Importing the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the dataset**
#
# Loading the given dataset astro_automobiles.csv into pandas dataframe using read_csv()

# %%
df = pd.read_csv('/content/sample_data/austo_automobile .csv')
df1 = df.copy()

# %% [markdown]
# # **Data Overview**
#
# Import the libraries - Load the data - Check the structure of the data - Check the types of the data - Check for and treat (if needed) missing values - Check the statistical summary - Check for and treat (if needed) data irregularities - Observations and Insights

# %% [markdown]
# **Displaying the first few rows of the dataset**

# %%
df.head()          ## By default it will return first 5 rows from the dataset
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53  Female   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300           70700
# 1           Yes         No             Yes   95500           70300
# 2            No         No             Yes   97300           60700
# 3           Yes         No             Yes   72500           70300
# 4            No         No             Yes   79700           60200
#
#    Total_salary  Price Make  Gener-male
# 0        149000  61000  SUV        True
# ...

# %% [markdown]
# *   The Profession column indicates whether the person is having Business or Salaried.
# *   The Marital_status column indicates whether the person is Married or Single.
# *   The Education column indicates whether the person pursed Post Graduation or Graduate.
# *   The Total_salary  column is the combined salary of the individual and their partner (if applicable).

# %% [markdown]
# **Checking the shape of the dataset**

# %%
df.shape
# Out:
# (1581, 14)

# %% [markdown]
#  The number of rows and columns present the given dataset
# 1.   The number of rows are 1581
# 2.   The number of columns are 14

# %% [markdown]
# **Checking the data types of the columns for the dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.1+ KB

# %% [markdown]
# *   All the column have 1581 observation except Gender and Partner_salary which has 1528 and 1475 observations indicating that ther are some missing values in them.
# *     Age, No_of_Dependents, Salary, Total_salary and Price belongs to numeric column.
# *   Partner_salary belongs to float type.
# *   Gender, Profession, Marital_Status, Education, Personal_loan, House_loan, Partner_working and Make belongs to categorical column.

# %% [markdown]
# **Getting the statistical summary for the dataset**

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     31.922201      8.425978     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  60392.220114  14674.825044  30000.0  51900.0
# Partner_salary    1581.0  19233.776091  19670.391171      0.0      0.0
# Total_salary      1581.0  79398.545225  24849.147996  30000.0  60500.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      54.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59500.0  71800.0   99300.0
# Partner_salary    25100.0  38100.0   80500.0
# Total_salary      78000.0  95900.0  149000.0
# Price             31000.0  47000.0   70000.0

# %% [markdown]
# *   The minimum age is 22 and maximum age is 54.
# *   The minimum salary is 30000 and maximum salary is 99300.
# *   The total salary a person gets in the range of 30600 to 148750.
# *   The price of the automobile starts from 18000 to 70000.

# %% [markdown]
# *   The data type of the Partner_salary column has been succesfully changed to int format
# *   There are now 6 numerical columns and 8 object type columns.

# %%
df.describe(include='all').T
# setting include='all' will get the statistical summary for both the numerical and categorical variables.
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     31.922201
# Gender              1581      3           Male  1199           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  60392.220114
# Partner_salary    1581.0    NaN            NaN   NaN  19233.776091
# Total_salary      1581.0    NaN            NaN   NaN  79398.545225
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %% [markdown]
# *   Male count(1199) are more compare to Female.
# *   The number of Salaried(896) are more compare to Business.
# *   The count of Married(1443) are more compare to Single.
# *   Sedan sales(702) are more compare to other automobiles.

# %% [markdown]
# Let's check the count of each unique category in each of the categorical/object type variables.

# %%
df['Marital_status'].value_counts()
# Out:
# Marital_status
# Married    1443
# Single      138
# Name: count, dtype: int64

# %% [markdown]
# The count of Married and Singles are 1443 and 138 respectively.

# %%
Married_to_working_partner = (df['Marital_status'] == 'Married') &  (df['Partner_working'] == 'Yes')
print(Married_to_working_partner.value_counts())

Married_to_non_working_partner = (df['Marital_status'] == 'Married') &  (df['Partner_working'] == 'No')
print(Married_to_non_working_partner.value_counts())

single_to_non_working_partner = (df['Marital_status'] == 'Single') &  (df['Partner_working'] == 'No')
print(single_to_non_working_partner.value_counts())

single_to_working_partner = (df['Marital_status'] == 'Single') &  (df['Partner_working'] == 'Yes')
print(single_to_working_partner.value_counts())
# Out:
# True     868
# False    713
# Name: count, dtype: int64
# False    1006
# True      575
# Name: count, dtype: int64
# False    1443
# True      138
# Name: count, dtype: int64
# False    1581
# Name: count, dtype: int64

# %% [markdown]
# *   Among 1443 married, 868 are having working partner and the remaining 575 are having non-working partner.
# *   138 are singles having non partner.

# %%
df['Profession'].value_counts()
# Out:
# Profession
# Salaried    896
# Business    685
# Name: count, dtype: int64

# %% [markdown]
# The count of profession: Salaried and Business are 896 and 685 respectively.

# %%
df['Education'].value_counts()
# Out:
# Education
# Post Graduate    985
# Graduate         596
# Name: count, dtype: int64

# %% [markdown]
# The count of Post Gratutaion and Gratutaion are 985 and 596 respectively.

# %%
df['Partner_working'].value_counts()
# Out:
# Partner_working
# Yes    868
# No     713
# Name: count, dtype: int64

# %% [markdown]
# The count of working and non-working partner are 868 and 713 respectively.

# %%
Sedan_Price_Range = df.groupby('Make').get_group('Sedan')['Price'].describe().T
SUV_Price_Range = df.groupby('Make').get_group('SUV')['Price'].describe().T
Hatchback_Price_Range = df.groupby('Make').get_group('Hatchback')['Price'].describe().T
print(Sedan_Price_Range)
print(SUV_Price_Range)
print(Hatchback_Price_Range)
# Out:
# count      702.000000
# mean     34603.988604
# std      11152.164304
# min      18000.000000
# 25%      24000.000000
# 50%      33000.000000
# 75%      44000.000000
# max      55000.000000
# Name: Price, dtype: float64
# count      297.000000
# mean     55824.915825
# std       9218.242714
# min      31000.000000
# 25%      51000.000000
# 50%      57000.000000
# 75%      63000.000000
# max      70000.000000
# Name: Price, dtype: float64
# count      582.000000
# mean     26474.226804
# std       4290.467640
# min      18000.000000
# 25%      23000.000000
# 50%      27000.000000
# 75%      30000.000000
# max      33000.000000
# Name: Price, dtype: float64

# %% [markdown]
# *   Sedan Car starting price ranges from 18000 to 55000.
# *   SUV Car starting price ranges from 31000 to 70000.
# *   Hatchback Car starting price ranges from 18000 to 33000.

# %% [markdown]
# ## **Handling the missing values**

# %% [markdown]
# Let's check how many missing values are present in each variable.

# %%
df.isnull().sum()            ## checking missing values across each columns
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# Gener-male          0
# dtype: int64

# %% [markdown]
# *  Gender and Partner_salary have 53 and 106 missing values in them.
# *  There are no missing values in other columns.

# %% [markdown]
# **Handling the missing values in Gender column**

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %% [markdown]
# *   The Gender column have 5 unique values in them.
# *   The speeling of Female is not correct, so it should be handled.

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       1199
# Female      329
# Unknown      53
# Name: count, dtype: int64

# %% [markdown]
# *   Male and Female counts are 1199 and 327 respectively.
# *   Femal and Femle count is 1 for each.
# *   There are 53 missing values in them.

# %% [markdown]
# We can replace the Femal and Femle values present in the Gender column with a Female.

# %%
df['Gender'].replace(['Femal', 'Femle'], ['Female', 'Female'], inplace=True)
# Out:
# <ipython-input-226-1e67c3656cdb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace(['Femal', 'Femle'], ['Female', 'Female'], inplace=True)

# %% [markdown]
# We can replace the null values present in the Gneder column with Unknown.

# %%
# Replacing NaN with Unknown
df['Gender'].fillna('Unknown', inplace =True)

# %% [markdown]
# Let's check the Gender columns again to ensure that the change has been executed properly.

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       1199
# Female      329
# Unknown      53
# Name: count, dtype: int64

# %% [markdown]
# *   Male and Female counts are 1199 and 329 respectively.
# *   There are 53 Unknown values in them.

# %% [markdown]
# **Handling the missing values in Partner_salary**

# %%
print(df['Partner_salary'].isnull().sum())
# Out:
# 0

# %% [markdown]
# There are total 106 missing value in Partner_salary column

# %% [markdown]
# By subtracting the Total_salary with Salary we get Partner_salary.

# %%
def get_partner_salary():
  df['Partner_salary'] = df['Total_salary'] - df['Salary']

  return df['Partner_salary']

df['Partner_salary'] = df['Partner_salary'].fillna(get_partner_salary())

# %% [markdown]
# Let's check the Partner_salary columns again to ensure that the change has been executed properly.

# %%
df['Partner_salary'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Converted the Partner_salary column from float to int data type

# %%
df['Partner_salary'] = df['Partner_salary'].astype(int)

# %% [markdown]
# Let's check the data types of the columns again to ensure that the change has been executed properly.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
#  14  Gener-male        1581 non-null   bool
# dtypes: bool(1), int64(6), object(8)
# memory usage: 174.6+ KB

# %% [markdown]
# *   The data type of the Partner_salary column has been succesfully changed to int format.
# *   There are now 6 numerical columns and 8 object type columns.

# %% [markdown]
# # **Univariate Analysis**
#
#
# - Explore all the variables (categorical and numerical) in the data - Check for and treat (if needed) outliers - Observations and Insights

# %% [markdown]
# **Understanding the distribution of "Age"**

# %%
sns.histplot(data = df, x = 'Age', kde = True)
plt.show()
sns.boxplot(data = df, x = "Age")
plt.show()

# %% [markdown]
# * The graph is right skewed, indicating that older individuals are less.
# * The largest number of people are of age 25-35 years old.
# * As age goes above 40, the number of people starts to drop.

# %% [markdown]
# **Understanding the distribution of Gender**

# %%
sns.countplot(data = df, x = "Gender", hue = "Gender")
plt.show()

# %% [markdown]
# *   The number of Male are more as compared to Female.

# %% [markdown]
# **Understanding the distribution of Profession**

# %%
sns.histplot(data = df, x = 'Profession', hue = 'Profession')
plt.show()

# %% [markdown]
# In terms of Profession the salaried individual are more comparatively the one who runs business.

# %% [markdown]
# **Understanding the distribution of No_of_Dependents**

# %%
sns.histplot(data = df, x = 'No_of_Dependents')
plt.show()
sns.countplot(data = df, x = 'No_of_Dependents', hue = 'No_of_Dependents')
plt.show()

# %% [markdown]
# *  Majority of the group have 2 or 3 dependency.
# *  There are relatively fewer people with 0 or 4 dependency.

# %% [markdown]
# **Understanding the distribution of Salary**

# %%
sns.histplot(data = df, x = 'Salary', kde = True)
plt.show()
sns.boxplot(data = df, x = "Salary")
plt.show()

# %% [markdown]
# * The Salary has normal distribution with slightly right-skewed.
# * The majority earn between 55000 to 75000, the small right skew tells that few earn high.
# * The median value is 60000.

# %% [markdown]
# **Understanding the distribution of 'Partner_salary'**

# %%
sns.histplot(data = df, x = 'Partner_salary', kde = True)
plt.show()
sns.boxplot(data = df, x = 'Partner_salary')
plt.show()

# %% [markdown]
# * The graph is highly right skewed. The majority of the salaries are on the lower end.
# * The median value of Partner_salary is 25000.

# %% [markdown]
# **Understanding the distribution of Total_salary**

# %%
sns.histplot(data = df, x = 'Total_salary', kde = True)
plt.show()
sns.boxplot(data = df, x = 'Total_salary')
plt.show()

# %% [markdown]
# * The "Total_salary" appears approximately normal but slightly right skewed.
# * Most individuals have a salary in the range 60000 to 100000.
# * The Median of Total salary is 80000.

# %% [markdown]
# **Treating the outliers using clip()**

# %%
def treat_outlier(df, col):
  Q1 = df['Total_salary'].quantile(0.25)
  Q3 = df['Total_salary'].quantile(0.75)

  IQR = Q3 - Q1
  lower_whisker = Q1 - 1.5 * IQR
  upper_whisker = Q3 + 1.5 * IQR

  df['Total_salary'] = df['Total_salary'].clip(lower_whisker, upper_whisker)

  return df

# %%
treat_outlier(df, 'Total_salary')
sns.boxplot(data = df, x = 'Total_salary');

# %% [markdown]
# **Understanding the distribution of Gender and Profession**

# %%
sns.countplot(data = df, x = 'Gender', hue = 'Profession');

# %% [markdown]
# In the given data set, the number of Salaried Males and Females are more comparatively with one who have business.

# %% [markdown]
# **Understanding the distribution between Make and Personal_loan**

# %%
sns.countplot(data = df, x = 'Make', hue = 'Personal_loan');

# %% [markdown]
# 1. SUV Owners:
#
#     * A significantly higher number of SUV owners do not have a personal loan
#       compared to those who do.
#
#     * This could imply that SUV owners may be more financially stable or less
#       reliant on personal loans.
#
#
#
# 2. Sedan Owners:
#
#     * More Sedan owners have a personal loan than not.
#
#     * This might suggest that individuals buying sedans are more likely to take
#       loans.
#
#
#
# 3. Hatchback Owners:
#
#     * The counts are nearly equal for both loan takers and non-loan takers.
#
#     * This could suggest that hatchback owners are a mixed group financially –
#       some may prefer to not to take loans, while others rely on loans.

# %% [markdown]
# **Understanding the distribution of Make**

# %%
sns.countplot(data = df, x = 'Make', hue = 'Make')
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# * Sedan is the most popular type, with over 700 units.
#
# * Hatchback comes second, with just under 600 units.
#
# * SUV is the least common, with about 300 units.

# %% [markdown]
# # **Bivariate Analysis**
#
# - Explore the relationship between all numerical variables - Explore the correlation between all numerical variables - Explore the relationship between categorical vs numerical variables

# %% [markdown]
# **Visualising relationship between all numerical variables**

# %%
plt.figure(figsize = (5,5))
sns.pairplot(data = df, diag_kind = 'kde')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# 1.  Salary vs. Total_Salary: Strong positive linear correlation.Higher Salary generally leads to higher Total_Salary.
#
# 2. Partner_Salary vs. Total_Salary: Also positively correlated, but more scattered.Many individuals have a Partner_Salary of 0 — indicating no partner or non-working partner.
#
# 3.  Age vs. Salary: Weak to moderate positive trend — older people tend to earn more.
#
# 4.  No_of_Dependents vs. Salary/Price: No clear linear relationship; data is scattered.
#
# 5. Total_Salary vs. Price: Positive relationship- higher total salary is associated with higher price Cars.
#
# 6. Salary vs. Price: positive correlation — higher earners tend to be associated with higher price Cars.

# %% [markdown]
# **Visualising the correlation between all numerical variables**

# %%
plt.figure(figsize = (4,4))
numeric_df = df.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(), annot = True, cbar = False, cmap = 'YlGnBu')
plt.show()

# %% [markdown]
# 1. Strong Positive Correlations
#
#     * Age and Price (0.80):Older individuals tend to be associated with higher
#       price Cars.
#     * Salary and Total_salary (0.64).
#     * Partner_salary and Total_salary (0.82).
#
#       Total_salary is the sum of Salary and Partner_salary.
#
#
# 2. Moderate Correlations
#
#     * Age and Salary (0.62):This suggests that salary tends to increase with
#       age.
#
#     * Partner_salary and Price (0.36):Indicates a moderate relationship between
#       a partner's salary and the price.
#
# 3. Low or No Significant Correlation
#
#     * No_of_Dependents with all other variables (max ~0.15):This variable does
#       not have any significant correlation with other numerical features in the dataset.

# %% [markdown]
# **Visualising the relationship between Age  vs Gender**
#
# ---

# %%
sns.barplot(data = df, x = 'Gender', y = 'Age', hue = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %% [markdown]
# *   In the given dataset an average age of females appears to be higher than that of males.
# *   This indicates that female individuals tend to be older than male.

# %% [markdown]
# **Visualising the relationship between Gender and Salary**

# %%
sns.barplot(data = df, x = 'Gender', y = 'Salary', hue = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# *   The average salary of females is higher than that of males.
#
# * Females appear to earn approximately above 65,000, while males earn below 60,000.

# %% [markdown]
# **Visualising the relationship between Education, Salary and Gender**

# %%
sns.barplot(data = df, x = 'Education', y = 'Salary', hue = 'Gender');

# %% [markdown]
# 1. Education vs. Salary
#
#     * Post Graduates earn significantly higher salaries compared to Graduates.
#
#     * The average salary for Post Graduates is well above 70,000.
#
#     * The average salary for Graduates is below 55,000.
#
# 2. Gender Comparison (within Education Levels)
#
#     * Post Graduate Level:
#
#         1. Females earn the highest among all groups—above 70,000.
#
#         2. Males earn slightly less—approximately 65,000.
#
#         3. Individuals with Unknown gender earn slightly less than males but
#            still around 65,000.
#
#     * Graduate Level:
#
#         1. Females again earn more than males—around 53,000.
#
#         2. Males earn approximately 45,000.
#
#         3. Unknown gender individuals earn slightly less than males—about 43,
#           000.

# %% [markdown]
# **Visualising the relationship between Marital_status and Total_salary**

# %%
sns.barplot(data = df, x = 'Marital_status', y = 'Total_salary', hue = 'Marital_status')
# Out:
# <Axes: xlabel='Marital_status', ylabel='Total_salary'>

# %% [markdown]
# *   People who are married have more than 80000 as Total_salary.
# *   People who are not married have less than 60000 as Total_salary.

# %% [markdown]
# **Visualising the relationship between Price and Make**

# %%
sns.barplot(data = df, x = 'Make', y = 'Price', hue = 'Make');

# %% [markdown]
# * SUVs Are the Most Expensive price of SUVs are more than 55000.
# * Sedans Are Mid-Range between SUV and Hatchback(more than 20000 and less than 35000).
# * Hatchbacks Are the Most Affordable(less than 25000).

# %% [markdown]
# **Visualizing the relationship between Age and Price with Gender as hue**

# %%
sns.lineplot(data = df, x = 'Age', y = 'Price', hue = 'Gender',errorbar=('ci', False));

# %% [markdown]
# 1. Price Increases with Age
#
#     * Across all gender categories, price generally increases with age, especially from age 30 to 50.
#
#     * Suggests that older individuals tend to purchase more expensive car,.
#
# 2. Gender Differences
#
#     * Male vs Female:
#
#         1. Up to age ~45: both genders follow a similar trend, with some small variations.
#
#         2. From age 45 to 50, females tend to spend slightly more than males, peaking higher.
#
#         3. After 50, both slightly decline or stabilize.
#
#     * Unknown Gender:
#
#         1. Maintains significantly lower price levels until age 30, then a sharp rise.

# %% [markdown]
# **Visualizing the relationship between Gender and Price with Make as hue**

# %%
sns.lineplot(data = df, x = 'Gender', y = 'Price', hue = 'Make', errorbar=('ci', False));

# %% [markdown]
# 1. SUVs:
#     * Males spend the most on SUVs (~$60,000).
#
#     * Females spend slightly less (~$54,000).
#
#     * The Unknown gender group pays the least (~$49,000).
#
#           This suggests SUVs are most popular and most valued among males.
#
# 2. Sedans:
#     * Females pay more for sedans ($43,000) compared to males ($34,000).
#
#     * The price drops significantly for the Unknown group (~$20,000).
#
#             Indicates that sedans are particularly preferred by female buyers,potentially due to a balance of comfort, size, and price.
#
# 3. Hatchbacks:
#     * Females pay the most (~$28,000),
#
#     * Followed by males (~$27,000),
#
#     * Then Unknown (~$19,000).
#             Pricing is more consistent across genders so it is considered as a budget-friendly car.

# %% [markdown]
# **Visualising the relationship between No_of_Dependents and Total_salary**

# %%
sns.barplot(data = df, x = 'No_of_Dependents', y = 'Total_salary', hue = 'No_of_Dependents');

# %% [markdown]
# 1. Sharp Increase from 0 to 1 Dependent:
#
#     * Individuals with no dependents earn the lowest total salary (~$59,000).
#
#     * Having 1 dependent boosts average total salary to ~$77,000, a ~30% increase.
#
# 2. Steady Growth After 1 Dependent:
#
#     * From 1 to 4 dependents, total salary gradually increases:
#
#         1. 2 dependents: ~$81,000
#
#         2. 3 dependents: ~$79,000 (a slight dip)
#
#         3. 4 dependents: ~$85,000 (highest)
#
# 3. Higher Dependents → Higher Salary:
#
#     * Generally, people with more dependents tend to earn higher total salaries.

# %% [markdown]
# **Visualising the relationship between House_loan and Price**

# %%
sns.barplot(data = df, x = 'House_loan', y = 'Price', hue = 'House_loan');

# %% [markdown]
# The individual who has the house loan tends to spend slightly less on cars than one who doesn't have a house loan.

# %% [markdown]
# **Visualising the relationship between Personal_loan and Price**

# %%
sns.barplot(data = df, x = 'Personal_loan', y = 'Price', hue = 'Personal_loan');

# %% [markdown]
# The individuals who have the personal loan tend to spend slightly less on cars than one who doesn't have a personal loan.

# %% [markdown]
# **Car Price vs House_loan Status with Personal_loan as hue**

# %%
sns.FacetGrid(df, col = 'House_loan', hue = 'Personal_loan').map(sns.histplot, 'Price');

# %% [markdown]
# * Customers without a house loan:
#
#     * Tend to buy more expensive cars(especially in the ₹40,000–₹60,000 range).
#
#     * Those with personal loans (blue bars) are still active in purchasing higher price cars.
#
# * Customers with a house loan:
#
#     * Prefer lower to mid-range cars (₹20,000–₹35,000).
#
#     * Very few spend above ₹40,000.

# %% [markdown]
# **Car Price vs Personal_loan Status with House_loan as hue**

# %%
sns.FacetGrid(df, col = 'Personal_loan', hue = 'House_loan').map(sns.histplot, 'Price');

# %% [markdown]
# * Customers without a personal loan:
#
#     * A significant number purchase higher-end cars (₹40,000–₹65,000).
#
#     * Most high spenders are not burdened with house loans (blue bars dominate right side).
#
#
# * Customers with a personal loan:
#
#     * Generally stick to mid-range cars (₹20,000–₹40,000).
#
#     * Having both personal and house loans is associated with minimal high-end car purchases.

# %% [markdown]
# # **Key Questions**
#
# Explore the data to answer the following key questions:
# 1. Do men tend to prefer SUVs more compared to women?
# 2. What is the likelihood of a salaried person buying a Sedan?
# 3. What evidence or data supports Sheldon Cooper's claim that a salaried male is an easier target for a SUV sale over a Sedan sale?
# 4. How does the the amount spent on purchasing automobiles vary by gender?
# 5. How much money was spent on purchasing automobiles by individuals who took a personal loan?
# 6. How does having a working partner influence the purchase of higher-priced cars?

# %% [markdown]
# **1.Do men tend to prefer SUVs more compared to women?**

# %%
df.groupby('Gender')['Make'].value_counts().T
# Out:
# Gender  Make
# Female  SUV          173
#         Sedan        141
#         Hatchback     15
# Male    Hatchback    565
#         Sedan        516
#         SUV          118
# Name: count, dtype: int64

# %% [markdown]
# *   No, from the above series it is clear that women prefer SUVs more compared to men.
# *   The count of women who prefer SUVs is 173 whereas count of men who prefer SUVs is 118.

# %% [markdown]
# **2. What is the likelihood of a salaried person buying a Sedan?**

# %%
print(df['Profession'].value_counts())
print(df.groupby('Profession')['Make'].value_counts().T)
# Out:
# Profession
# Salaried    896
# Business    685
# Name: count, dtype: int64
# Profession  Make
# Business    Sedan        306
#             Hatchback    290
#             SUV           89
# Salaried    Sedan        396
#             Hatchback    292
#             SUV          208
# Name: count, dtype: int64

# %% [markdown]
# * Among 1528 total count of Profession column
#     1. 864 are Salaried
#         1. 370 are likely to buy Sedan.
#         2. 291 are likely to buy a Hatchback.
#         3. 203 are likely to buy an SUV.
#     2. 664 are having Business
#         1. 287 are likely to buy a Sedan.
#         2. 289 are likely to buy a Hatchback.
#         3. 88 are likely to buy an SUV.
#
# * 42.82% of salaried people are likely to buy a Sedan.

# %% [markdown]
# **3. What evidence or data supports Sheldon Cooper's claim that a salaried male is an easier target for a SUV sale over a Sedan sale?**

# %%
df.groupby(['Gender', 'Profession']).get_group(('Male', 'Salaried'))['Make'].value_counts()
# Out:
# Make
# Sedan        279
# Hatchback    276
# SUV           85
# Name: count, dtype: int64

# %%
SUV_to_Sedan_ratio = (85/279)
print(SUV_to_Sedan_ratio)
sedan_to_SUV_ratio = (279/85)
print(sedan_to_SUV_ratio)
# Out:
# 0.3046594982078853

# %%
plt.figure(figsize = (7, 5))
df1["Gener-male"] = df1['Gender'] == 'Male'
sns.barplot(data = df, x = df['Gender'] == 'Male', y = df['Profession'], hue = 'Make', errorbar=('ci', False));
plt.xlabel("Gender-Male")
# Out:
# Text(0.5, 0, 'Gender-Male')

# %% [markdown]
# The data doesn't supports Sheldon Cooper's claim. In fact, salaried males are over three times more likely to buy a Sedan than an SUV, making them a harder target for SUV sales.

# %% [markdown]
# **4. How does the the amount spent on purchasing automobiles vary by gender?**

# %%
df.groupby('Gender')['Price'].mean()
# Out:
# Gender
# Female    47705.167173
# Male      32817.347790
# Name: Price, dtype: float64

# %% [markdown]
# * Females spent more on purchasing automobiles compared to Male.
# * The average price spent by females is 47705.16.
# * The average price spent by Male is 32817.34.

# %% [markdown]
# **5. How much money was spent on purchasing automobiles by individuals who took a personal loan?**

# %%
df.groupby('Personal_loan')['Price'].sum()
# Out:
# Personal_loan
# No     28399000
# Yes    26644000
# Name: Price, dtype: int64

# %% [markdown]
# *   An amount of 26644000 was spent on purchasing automobiles by individuals who took a personal loan.
# *   An amount of 28399000  was spent on purchasing automobiles by individuals who did not take a personal loan.

# %% [markdown]
# **6. How does having a working partner influence the purchase of higher-priced cars?**

# %%
df.groupby('Partner_working')['Price'].mean()
# Out:
# Partner_working
# No     36378.260870
# Yes    35730.310263
# Name: Price, dtype: float64

# %% [markdown]
# An average of 35730.31 amount spent to purchase the automobile who have working partner, which is more than the amount spent to purchase the automobile who don't have working partner.
#
#
#
# This indicates that a working partner influence the purchase of higher-priced cars.

# %% [markdown]
# **7. Who tends to take more Personal loan: salaried or business holders?**

# %%
df.groupby('Profession')['Personal_loan'].value_counts()
# Out:
# Profession  Personal_loan
# Business    Yes              363
#             No               322
# Salaried    No               467
#             Yes              429
# Name: count, dtype: int64

# %% [markdown]
# * The business holders tend to take less personal loan compared to salaried individuals.
# * Among 1581 observations:
#     * 685 are business holders: 363 take loans and 322 don't take.
#     * 896 are salaried individuals: 429 take loan and 467 don't take.

# %% [markdown]
# **8. Who tends to take more house loan: salaried or business holders?**

# %%
df.groupby('Profession')['House_loan'].value_counts()
# Out:
# Profession  House_loan
# Business    No            456
#             Yes           229
# Salaried    No            598
#             Yes           298
# Name: count, dtype: int64

# %% [markdown]
# * The business holders tend to take less house loans compared to salaried individuals.
# * Among 1581 observations:
#     * 685 are business holders: 229 take loan and 456 don't take.
#     * 896 are salaried individuals: 298 take loan and 598 don't take.

# %% [markdown]
# **9. Who tends to take more Personal loan: Graduates or Post Graduates?**

# %%
df.groupby('Education')['Personal_loan'].value_counts()
# Out:
# Education      Personal_loan
# Graduate       Yes              308
#                No               288
# Post Graduate  No               501
#                Yes              484
# Name: count, dtype: int64

# %% [markdown]
# * The Graduates tend to take less personal loan compared to Postgraduate individuals.
# * Among 1581 observations:
#     * 596 are Graduates: 308 take loan and 288 don't take.
#     * 985 are Post Graduates: 484 take loan and 501 doesn't take.

# %% [markdown]
# **10. Who tends to take more House loan: Graduates or Post Graduates?**

# %%
df.groupby('Education')['House_loan'].value_counts()
# Out:
# Education      House_loan
# Graduate       No            394
#                Yes           202
# Post Graduate  No            660
#                Yes           325
# Name: count, dtype: int64

# %% [markdown]
# * The Graduates tend to take less house loan compared to Postgraduate individuals.
# * Among 1581 observations:
#     * 596 are Graduates: 202 takes loan and 394 doesn't take.
#     * 985 are Post Graduates: 325 takes loan and 660 doesn't take

# %% [markdown]
# # Actionable Insights and Recommendations

# %% [markdown]
# **Insights**

# %% [markdown]
# I analyzed a dataset of austro_automobile in detail.The dataset contains three different cars and the sales of these are affected by few factors.
#
# From the analyzes i have been able to conclude that -
#
# * Most buyers are young (avg. age 32), salaried, married males with a postgraduate degree.
#
# * Sedans are the top car choice, followed by SUVs and hatchbacks.
#
# * Cars are typically priced between ₹25,000 and ₹50,000, with few high-end purchases.
#
# * Older age and higher income strongly correlate with buying more expensive cars.
#
# * Dual-income households (with working partners) have significantly higher total income.
#
# * Families with more dependents tend to spend slightly less on cars.
#
# * The individual with Postgraduate and Salaried are more likely to use personal loans.
#
# * The Postgraduates are more likely to use house loans.

# %% [markdown]
# **Actionable Recommendations**

# %% [markdown]
# * Married postgraduates in the 30–40 age group are high-value targets because they show the strongest purchase behavior.
# * Sedans are the most popular type of car among customers—keep them in stock and promote them.
# * Prioritize marketing to dual-income families beacuse they have significantly more purchasing power.
# * Launch targeted promotions for mid-range cars (₹25,000–₹35,000) where most customers are buying—boost volume here.
# * Show different car models and offers depending on income, loan status, and age.
# * Suggest higher-end cars to older and higher-earning buyers; offer budget options to younger, low-income customers.
# * Provide Offers like free maintenance, extended warranty, or child safety features for customers with multiple dependents.
# * Prioritize marketing to postgraduates—they are more likely to take loans and make purchase decisions.
# * Prioritize marketing to who don’t have house or personal loans because they are more likely to buy higher-priced cars.
